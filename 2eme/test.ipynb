# %%
import pandas as pd

# Chargement des données
file_path = 'Phase1.csv'
data = pd.read_csv(file_path)

# Affichage des premières lignes, types de données, et statistiques descriptives
first_rows = data.head()

# %%
data_types = data.dtypes

descriptive_statistics = data.describe(include='all')


first_rows, data_types, descriptive_statistics
# Out:
# (   Unnamed: 0  duration protocol_type   service flag  src_bytes  dst_bytes  \
#  0           0         0           tcp  ftp_data   SF        491          0
#  1           1         0           udp     other   SF        146          0
#  2           3         0           tcp      http   SF        232       8153
#  3           4         0           tcp      http   SF        199        420
#  4          12         0           tcp      http   SF        287       2251
#
#     land  wrong_fragment  urgent  ...  dst_host_srv_count  \
#  0     0               0       0  ...                  25
#  1     0               0       0  ...                   1
#  2     0               0       0  ...                 255
#  3     0               0       0  ...                 255
#  4     0               0       0  ...                 219
#
#     dst_host_same_srv_rate  dst_host_diff_srv_rate  \
#  0                    0.17                    0.03
#  1                    0.00                    0.60
# ...
