# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import datasets
import numpy as np

# %%
xls = pd.ExcelFile("EastWestAirlinesCluster.xlsx") #lire le fichier excel avec pandas
df1 = pd.read_excel(xls, 'data') #lire le contenu de la feuille data et le stocker dans un dataframe

df1.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 xls = pd.ExcelFile("EastWestAirlinesCluster.xlsx") #lire le fichier excel avec pandas
#       2 df1 = pd.read_excel(xls, 'data') #lire le contenu de la feuille data et le stocker dans un dataframe
#       4 df1.info()
#
# NameError: name 'pd' is not defined

# %%
from sklearn.preprocessing import scale #la fonction de normalisation à partir de la bibliothèque sklearn
data = scale(df1) 
model=KMeans(n_clusters=3,random_state=0)
model.fit(df1)
labels=model.labels_
print(model.labels_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 from sklearn.preprocessing import scale #la fonction de normalisation à partir de la bibliothèque sklearn
# ----> 2 data = scale(df1)
#       3 model.fit(df1)
#       4 labels=model.labels_
#
# NameError: name 'df1' is not defined

# %%
print(labels[:300])
# Out:
# [2 2 2 2 0 2 2 2 1 0 2 0 2 2 2 2 2 2 2 2 0 0 2 2 0 2 2 2 2 2 0 2 0 2 2 0 2
#  2 2 2 2 2 2 1 0 0 2 2 2 2 0 2 0 0 2 2 2 2 2 2 0 2 2 1 2 2 2 2 0 2 2 0 1 2
#  0 0 0 0 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 0 0 2 2 0 2 2 2 2 2 2 2 2 0 2 2 2 0
#  0 0 2 0 2 0 1 0 2 2 0 2 2 2 0 1 0 2 0 2 2 0 0 0 0 0 0 0 2 2 2 2 0 2 2 2 2
#  2 2 2 1 0 2 2 0 0 2 0 2 2 0 0 2 2 2 2 1 1 2 2 2 1 0 0 1 0 2 2 2 2 0 2 2 2
#  2 1 0 1 2 0 0 1 2 2 0 2 0 2 0 2 2 2 0 2 2 0 2 2 2 0 2 0 2 2 0 2 2 0 0 1 0
#  2 2 0 2 0 0 2 0 0 2 2 2 2 0 2 0 2 2 0 2 0 0 1 2 0 2 0 2 2 2 2 2 2 0 1 2 0
#  1 0 2 0 2 2 0 2 2 2 2 0 0 2 2 2 1 2 0 2 2 0 2 0 0 2 0 2 2 0 2 1 0 0 2 2 0
#  2 0 0 2]

# %%
plt.scatter( df1.Bonus_miles,df1.Balance,s=5)
plt.xlabel('bonus Miles')
plt.ylabel('balance')
plt.title('K-means Clustering')

plt.show()

# %%
colormap=np.array(['Red','green','blue'])

#Visualisation des clusters formés par K-Means
plt.scatter(df1.Bonus_miles,df1.Balance,c=colormap[model.labels_],s=4)

# %%
label_0 = np.where(labels == 0) #récupérer les index des éléments du cluster 0 et les mettre dans label_0
label_1 = np.where(labels == 1) #récupérer les  index des éléments du cluster 1 et les mettre dans label_0
label_2 = np.where(labels == 2) #récupérer les index des éléments du cluster 2 et les mettre dans label_0
print(label_0[0].shape, label_1[0].shape,label_2[0].shape  )
# Out:
# (838,) (90,) (3071,)

# %%
df1_labels_0=df1.iloc[label_0]
df1_labels_0.describe()
# Out:
#                ID#        Balance   Qual_miles   cc1_miles   cc2_miles  \
# count   838.000000     838.000000   838.000000  838.000000  838.000000
# mean   1596.009547  161739.806683   258.042959    2.998807    1.009547
# std    1046.510886   56651.548573  1071.091633    1.532990    0.128977
# min       5.000000   76552.000000     0.000000    1.000000    1.000000
# 25%     688.250000  118975.500000     0.000000    1.000000    1.000000
# 50%    1505.000000  143766.500000     0.000000    3.000000    1.000000
# 75%    2425.750000  193382.500000     0.000000    4.000000    1.000000
# max    3984.000000  350608.000000  9325.000000    5.000000    3.000000
#
#         cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  838.000000     838.000000   838.000000         838.000000
# mean     1.028640   33588.584726    17.081146         892.225537
# std      0.291891   30595.316392     9.999909        2123.823121
# min      1.000000       0.000000     0.000000           0.000000
# ...

# %%
df1_labels_1=df1.iloc[label_1]
df1_labels_1.describe()
# Out:
#                ID#       Balance   Qual_miles  cc1_miles  cc2_miles  \
# count    90.000000  9.000000e+01    90.000000  90.000000  90.000000
# mean    951.933333  5.426476e+05   490.888889   3.200000   1.033333
# std     869.745459  2.412754e+05  1225.326963   1.663893   0.180511
# min       9.000000  3.525080e+05     0.000000   1.000000   1.000000
# 25%     312.500000  3.834642e+05     0.000000   1.000000   1.000000
# 50%     624.500000  4.502495e+05     0.000000   3.500000   1.000000
# 75%    1499.000000  6.202218e+05     0.000000   5.000000   1.000000
# max    3811.000000  1.704838e+06  7210.000000   5.000000   2.000000
#
#        cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  90.000000      90.000000    90.000000          90.000000
# mean    1.033333   52160.977778    20.288889        1719.044444
# std     0.316228   50539.913076    10.735057        2181.823796
# min     1.000000       0.000000     0.000000           0.000000
# ...

# %%
df1_labels_2=df1.iloc[label_2]
df1_labels_2.describe()
# Out:
#                ID#        Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3071.000000    3071.000000   3071.000000  3071.000000  3071.000000
# mean   2160.251710   35804.449365    102.863562     1.769782     1.015304
# std    1154.116112   25763.753275    643.746070     1.176900     0.151303
# min       1.000000       0.000000      0.000000     1.000000     1.000000
# 25%    1193.500000   14541.000000      0.000000     1.000000     1.000000
# 50%    2214.000000   29667.000000      0.000000     1.000000     1.000000
# 75%    3182.500000   53903.000000      0.000000     3.000000     1.000000
# max    4021.000000  100992.000000  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3071.000000    3071.000000  3071.000000        3071.000000
# mean      1.007164   11631.559101     9.852165         305.230869
# std       0.152975   17034.117534     8.720056        1031.518684
# ...

# %% [markdown]
# La difference entre CHA et KMEANS est que les resultats changent chaque fois qu'on fais RUN dans Kmeans parce que le seed est choisi aléatoirement, contrairement a CHA.
